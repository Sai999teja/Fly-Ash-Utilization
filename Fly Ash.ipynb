# %%
import pandas as pd

# %%
data = pd.read_csv("Fly Ash - Sheet1 (1).csv")

# %%
data                              #data_used_for_machinelearning_model
# Out:
#     Year  Fly  Ash Generation  Fly Ash Utilization  Pecentage of Utilization
# 0   1997                68.88                 6.64                      9.63
# 1   1998                78.06                 8.43                     10.80
# 2   1999                78.99                 9.22                     11.68
# 3   2000                74.03                 8.91                     12.03
# 4   2001                86.29                13.54                     15.70
# 5   2002                82.81                15.57                     18.80
# 6   2003                91.65                20.79                     22.68
# 7   2004                96.28                28.29                     29.39
# 8   2005                98.57                37.49                     38.04
# 9   2006                98.97                45.22                     45.69
# 10  2007               108.15                55.01                     50.86
# ...

# %%
import sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
x = data[['Year']]

# %%
y = data[['Fly  Ash Generation']]

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model2 = LinearRegression()

# %%
y2 = data[['Fly Ash Utilization']]

# %%
model2.fit(x,y2)
# Out:
# LinearRegression()

# %%
import pickle

# %%
pickle.dump(model,open('fly_model.pkl','wb'))

# %%
pickle.dump(model2,open('fly_model2.pkl','wb'))

# %%
model.predict([[2037]])
# Out:
# array([[316.29688986]])

# %%
model.predict([[2070]])y
# Out:
#   File "<ipython-input-69-a9fc1785fe43>", line 1
#     model.predict([[2070]])y
#                            ^
# SyntaxError: invalid syntax

# %%
x
# Out:
#     Year
# 0   1997
# 1   1998
# 2   1999
# 3   2000
# 4   2001
# 5   2002
# 6   2003
# 7   2004
# 8   2005
# 9   2006
# 10  2007
# 11  2008
# 12  2009
# 13  2010
# 14  2011
# 15  2012
# 16  2013
# 17  2014
# 18  2015
# 19  2016
# 20  2017
# 21  2018
# 22  2019
# 23  2020

# %%
data.dtypes
# Out:
# Year                          int64
# Fly  Ash Generation         float64
# Fly Ash Utilization         float64
# Pecentage of Utilization    float64
# dtype: object

# %%
y
# Out:
#     Fly  Ash Generation
# 0                 68.88
# 1                 78.06
# 2                 78.99
# 3                 74.03
# 4                 86.29
# 5                 82.81
# 6                 91.65
# 7                 96.28
# 8                 98.57
# 9                 98.97
# 10               108.15
# 11               116.94
# 12               116.69
# 13               123.54
# 14               131.09
# 15               145.41
# 16               163.56
# 17               172.87
# 18               184.14
# 19               176.74
# 20               169.25
# 21               196.44
# 22               217.04
# 23               226.14
